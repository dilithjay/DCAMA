# %%
# !python train.py --datapath "datasets" \
           --benchmark serp \
           --fold 4 \
           --bsz 8 \
           --nworker 0 \
           --backbone resnet50 \
           --logpath "./logs" \
           --lr 1e-3 \
           --nepoch 1000
# Out:
# /home/dilith/anaconda3/envs/ml_env/lib/python3.9/site-packages/torch/nn/modules/conv.py:132: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   (out_channels, in_channels // groups, *kernel_size), **factory_kwargs))
#
# :==================== Start =====================
# |             datapath: datasets
# |            benchmark: serp
# |                 fold: 4
# |                  bsz: 8
# |              nworker: 0
# |             backbone: resnet50
# | feature_extractor_path:
# |              logpath: ./logs
# |                   lr: 0.001
# |               nepoch: 1000
# |           local_rank: 0
# |                 load:
# |                nshot: 1
# ...

# %%
# !python train.py --datapath "datasets" \
           --benchmark serp \
           --fold 3 \
           --bsz 8 \
           --nworker 0 \
           --backbone resnet50 \
           --logpath "./logs" \
           --lr 1e-3 \
           --nepoch 1000
# Out:
# /home/dilith/anaconda3/envs/ml_env/lib/python3.9/site-packages/torch/nn/modules/conv.py:132: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   (out_channels, in_channels // groups, *kernel_size), **factory_kwargs))
#
# :==================== Start =====================
# |             datapath: datasets
# |            benchmark: serp
# |                 fold: 3
# |                  bsz: 8
# |              nworker: 0
# |             backbone: resnet50
# | feature_extractor_path:
# |              logpath: ./logs
# |                   lr: 0.001
# |               nepoch: 1000
# |           local_rank: 0
# |                 load:
# |                nshot: 1
# ...

# %%
# !python train.py --datapath "datasets" \
           --benchmark serp \
           --fold 2 \
           --bsz 8 \
           --nworker 0 \
           --backbone resnet50 \
           --logpath "./logs" \
           --lr 1e-3 \
           --nepoch 1000
# Out:
# /home/dilith/anaconda3/envs/ml_env/lib/python3.9/site-packages/torch/nn/modules/conv.py:132: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   (out_channels, in_channels // groups, *kernel_size), **factory_kwargs))
#
# :==================== Start =====================
# |             datapath: datasets
# |            benchmark: serp
# |                 fold: 2
# |                  bsz: 8
# |              nworker: 0
# |             backbone: resnet50
# | feature_extractor_path:
# |              logpath: ./logs
# |                   lr: 0.001
# |               nepoch: 1000
# |           local_rank: 0
# |                 load:
# |                nshot: 1
# ...

# %%
# !python train.py --datapath "datasets" \
           --benchmark serp \
           --fold 1 \
           --bsz 8 \
           --nworker 0 \
           --backbone resnet50 \
           --logpath "./logs" \
           --lr 1e-3 \
           --nepoch 1000
# Out:
# /home/dilith/anaconda3/envs/ml_env/lib/python3.9/site-packages/torch/nn/modules/conv.py:132: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   (out_channels, in_channels // groups, *kernel_size), **factory_kwargs))
#
# :==================== Start =====================
# |             datapath: datasets
# |            benchmark: serp
# |                 fold: 1
# |                  bsz: 8
# |              nworker: 0
# |             backbone: resnet50
# | feature_extractor_path:
# |              logpath: ./logs
# |                   lr: 0.001
# |               nepoch: 500
# |           local_rank: 0
# |                 load:
# |                nshot: 1
# ...

# %%
# !python train.py --datapath "datasets" \
           --benchmark serp \
           --fold 0 \
           --bsz 8 \
           --nworker 0 \
           --backbone resnet50 \
           --logpath "./logs" \
           --lr 1e-3 \
           --nepoch 1000
# Out:
# /home/dilith/anaconda3/envs/ml_env/lib/python3.9/site-packages/torch/nn/modules/conv.py:132: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   (out_channels, in_channels // groups, *kernel_size), **factory_kwargs))
#
# :==================== Start =====================
# |             datapath: datasets
# |            benchmark: serp
# |                 fold: 0
# |                  bsz: 8
# |              nworker: 0
# |             backbone: resnet50
# | feature_extractor_path:
# |              logpath: ./logs
# |                   lr: 0.001
# |               nepoch: 1000
# |           local_rank: 0
# |                 load:
# |                nshot: 1
# ...

# %%
# !zip -r model.zip /content/DCAMA/logs/train/fold_0_1228_053317/
# Out:
# 	zip warning: name not matched: /content/DCAMA/logs/train/fold_0_1228_053317/
#
# zip error: Nothing to do! (try: zip -r model.zip . -i /content/DCAMA/logs/train/fold_0_1228_053317/)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/DCAMA/logs/train/fold_*/ /content/drive/MyDrive/FYP

# %%
from glob import glob
import os

glob(os.path.join("/content/DCAMA/datasets/Serp/4", "train", '*.npy'))
